# %% [markdown]
# <a href="https://colab.research.google.com/github/Haniasha/Azur/blob/main/Sample_Car_Financing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sample

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Datasets/car_financing.csv"
df = pd.read_csv(path)
df
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0        1          34689.96     687.23         202.93          484.30
# 1        2          34205.66     687.23         200.10          487.13
# 2        3          33718.53     687.23         197.25          489.98
# 3        4          33228.55     687.23         194.38          492.85
# 4        5          32735.70     687.23         191.50          495.73
# ..     ...               ...        ...            ...             ...
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate       car_type
# 0       34205.66    60         0.0702  Toyota Sienna
# ...

# %%
df.shape
# Out:
# (408, 9)

# %%
df.columns
# Out:
# Index(['Month', 'Starting Balance', 'Repayment', 'Interest Paid',
#        'Principal Paid', 'New Balance', 'term', 'interest_rate', 'car_type'],
#       dtype='object')

# %%
df.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %%
df.tail()
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate   car_type
# 403      3164.64    60          0.029  VW Golf R
# 404      2376.27    60          0.029  VW Golf R
# 405      1586.00    60          0.029  VW Golf R
# 406       793.82    60          0.029  VW Golf R
# 407        -0.28    60          0.029  VW Golf R

# %%
df.describe()
# Out:
#             Month  Starting Balance    Repayment  Interest Paid  \
# count  408.000000        408.000000   408.000000     408.000000
# mean    26.970588      17562.870343   712.134118      56.715123
# std     16.207776      11224.423084   247.447947      40.775353
# min      1.000000        395.410000   396.820000       1.280000
# 25%     13.000000       8557.900000   486.740000      26.257500
# 50%     26.000000      16262.230000   661.995000      50.640000
# 75%     39.250000      25285.055000   796.010000      76.357500
# max     60.000000      44409.600000  1289.530000     202.930000
#
#        Principal Paid   New Balance        term  interest_rate
# count      408.000000    408.000000  408.000000     408.000000
# mean       655.418995  16907.451348   52.941176       0.039603
# std        245.361625  11168.974693    9.268926       0.013414
# min        326.620000     -0.490000   36.000000       0.029000
# 25%        476.972500   7832.080000   48.000000       0.029000
# ...

# %%
label = "price"
numerical_features = np.array(["Month", "Starting Balance", "Repayment", \
                               "Interest Paid", "Principal Paid", "New Balance", "term", \
                               "interest_rate"])
non_numerical_features = np.array([column for column in df.columns \
                                   if column not in numerical_features and \
                                      column != label])

# %%
df[numerical_features].describe()
# Out:
#             Month  Starting Balance    Repayment  Interest Paid  \
# count  408.000000        408.000000   408.000000     408.000000
# mean    26.970588      17562.870343   712.134118      56.715123
# std     16.207776      11224.423084   247.447947      40.775353
# min      1.000000        395.410000   396.820000       1.280000
# 25%     13.000000       8557.900000   486.740000      26.257500
# 50%     26.000000      16262.230000   661.995000      50.640000
# 75%     39.250000      25285.055000   796.010000      76.357500
# max     60.000000      44409.600000  1289.530000     202.930000
#
#        Principal Paid   New Balance        term  interest_rate
# count      408.000000    408.000000  408.000000     408.000000
# mean       655.418995  16907.451348   52.941176       0.039603
# std        245.361625  11168.974693    9.268926       0.013414
# min        326.620000     -0.490000   36.000000       0.029000
# 25%        476.972500   7832.080000   48.000000       0.029000
# ...

# %%
df[non_numerical_features].describe()
# Out:
#          car_type
# count         408
# unique          4
# top     VW Golf R
# freq          144

# %%
df[non_numerical_features].nunique()
# Out:
# car_type    4
# dtype: int64

# %%
for feature in non_numerical_features:
  print("{:22s}: {}".format(feature, df[feature].unique()))
# Out:
# car_type              : ['Toyota Sienna' 'Toyota Corolla' 'Toyota Carolla' 'VW Golf R']

# %%
df.count()
# Out:
# Month               408
# Starting Balance    408
# Repayment           408
# Interest Paid       408
# Principal Paid      408
# New Balance         408
# term                408
# interest_rate       408
# car_type            408
# dtype: int64

# %%
df.corr()
# Out:
#                      Month  Starting Balance  Repayment  Interest Paid  \
# Month             1.000000         -0.807093  -0.140537      -0.680109
# Starting Balance -0.807093          1.000000   0.365767       0.797418
# Repayment        -0.140537          0.365767   1.000000       0.133342
# Interest Paid    -0.680109          0.797418   0.133342       1.000000
# Principal Paid   -0.028708          0.236358   0.986344      -0.031709
# New Balance      -0.810469          0.999772   0.345914       0.802074
# term              0.285941          0.023595  -0.491489       0.194771
# interest_rate     0.091180         -0.099216  -0.310194       0.447759
#
#                   Principal Paid  New Balance      term  interest_rate
# Month                  -0.028708    -0.810469  0.285941       0.091180
# Starting Balance        0.236358     0.999772  0.023595      -0.099216
# Repayment               0.986344     0.345914 -0.491489      -0.310194
# ...

# %%
px.imshow(df.corr())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for feature in numerical_features:
  fig = px.histogram(df, x=feature, marginal="box")
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for feature in non_numerical_features:
  fig = px.histogram(df, x=feature)
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
